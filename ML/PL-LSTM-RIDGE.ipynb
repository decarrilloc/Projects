# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import poisson
from sklearn.metrics import f1_score
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler

# %%
data=pd.read_csv(r'C:\Users\enriq\Apple\matches_pl_final.csv')
data.columns = [c.lower() for c in data.columns]

# %%
data['comp'].unique()
# Out:
# array(['Premier League', 'Europa Lg', 'EFL Cup', 'FA Cup',
#        'Community Shield', 'Champions Lg', 'Conf Lg', 'Super Cup'],
#       dtype=object)

# %%
data=data[data['comp']=='Premier League']

# %%
data=data.drop(['attendance','captain','formation','referee','match report','notes',],axis=1)
data
# Out:
#       unnamed: 0        date   time            comp         round  day venue  \
# 0              0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away
# 1              1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home
# 2              2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away
# 3              3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home
# 4              4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home
# ...          ...         ...    ...             ...           ...  ...   ...
# 1879          38  2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away
# 1880          39  2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home
# 1881          40  2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away
# 1882          41  2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away
# 1883          42  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home
#
#      result   gf   ga  ...  lost  blocks   sh  pass   int  tkl+int   clr  err  \
# 0         W  2.0  0.0  ...  16.0    17.0  6.0  11.0   9.0     38.0  24.0  0.0
# 1         W  4.0  2.0  ...   3.0     9.0  1.0   8.0   8.0     16.0  12.0  0.0
# 2         W  3.0  0.0  ...   7.0    11.0  0.0  11.0  10.0     24.0  20.0  1.0
# 3         W  2.0  1.0  ...   4.0    17.0  2.0  15.0   7.0     22.0   5.0  1.0
# 4         W  2.0  1.0  ...   5.0     4.0  0.0   4.0   8.0     18.0  13.0  0.0
# ...     ...  ...  ...  ...   ...     ...  ...   ...   ...      ...   ...  ...
# 1879      L    0    2  ...   9.0    12.0  7.0   5.0  14.0     26.0   9.0  0.0
# 1880      L    0    4  ...   9.0    16.0  4.0  12.0   9.0     21.0  20.0  1.0
# 1881      L    0    3  ...   9.0    14.0  7.0   7.0   5.0     24.0  37.0  0.0
# 1882      D    1    1  ...  19.0     8.0  5.0   3.0   9.0     33.0  23.0  0.0
# 1883      L    0    5  ...  10.0     4.0  3.0   1.0  11.0     25.0   7.0  1.0
#
#       season         team
# 0       2023      Arsenal
# 1       2023      Arsenal
# 2       2023      Arsenal
# 3       2023      Arsenal
# 4       2023      Arsenal
# ...      ...          ...
# 1879    2022  NorwichCity
# 1880    2022  NorwichCity
# 1881    2022  NorwichCity
# 1882    2022  NorwichCity
# 1883    2022  NorwichCity
#
# [1520 rows x 95 columns]

# %%
#Loss or draw = 0, win=1
data["target"] = (data["result"] == "W").astype("int")
data["venue_code"] = data["venue"].astype("category").cat.codes
data["opp_code"] = data["opponent"].astype("category").cat.codes

# %%
data
# Out:
#       unnamed: 0        date   time            comp         round  day venue  \
# 0              0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away
# 1              1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home
# 2              2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away
# 3              3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home
# 4              4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home
# ...          ...         ...    ...             ...           ...  ...   ...
# 1879          38  2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away
# 1880          39  2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home
# 1881          40  2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away
# 1882          41  2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away
# 1883          42  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home
#
#      result   gf   ga  ...  pass   int  tkl+int   clr  err  season  \
# 0         W  2.0  0.0  ...  11.0   9.0     38.0  24.0  0.0    2023
# 1         W  4.0  2.0  ...   8.0   8.0     16.0  12.0  0.0    2023
# 2         W  3.0  0.0  ...  11.0  10.0     24.0  20.0  1.0    2023
# 3         W  2.0  1.0  ...  15.0   7.0     22.0   5.0  1.0    2023
# 4         W  2.0  1.0  ...   4.0   8.0     18.0  13.0  0.0    2023
# ...     ...  ...  ...  ...   ...   ...      ...   ...  ...     ...
# 1879      L    0    2  ...   5.0  14.0     26.0   9.0  0.0    2022
# 1880      L    0    4  ...  12.0   9.0     21.0  20.0  1.0    2022
# 1881      L    0    3  ...   7.0   5.0     24.0  37.0  0.0    2022
# 1882      D    1    1  ...   3.0   9.0     33.0  23.0  0.0    2022
# 1883      L    0    5  ...   1.0  11.0     25.0   7.0  1.0    2022
#
#              team  target  venue_code  opp_code
# 0         Arsenal       1           0         7
# 1         Arsenal       1           1        11
# 2         Arsenal       1           0         2
# 3         Arsenal       1           1         9
# 4         Arsenal       1           1         1
# ...           ...     ...         ...       ...
# 1879  NorwichCity       0           0         1
# 1880  NorwichCity       0           1        21
# 1881  NorwichCity       0           0        11
# 1882  NorwichCity       0           0        22
# 1883  NorwichCity       0           1        19
#
# [1520 rows x 98 columns]

# %%
#Data is available up to week 27
data[(data['round']=='Matchweek 27') &  (data['season']==2023)]
# Out:
#      unnamed: 0        date   time            comp         round  day venue  \
# 36           36  2023-03-12  14:00  Premier League  Matchweek 27  Sun  Away
# 89           40  2023-03-11  17:30  Premier League  Matchweek 27  Sat  Away
# 146          43  2023-03-12  14:00  Premier League  Matchweek 27  Sun  Home
# 199          38  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Home
# 249          38  2023-03-11  12:30  Premier League  Matchweek 27  Sat  Away
# 296          33  2023-03-12  16:30  Premier League  Matchweek 27  Sun  Home
# 340          31  2023-03-12  14:00  Premier League  Matchweek 27  Sun  Home
# 383          30  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Away
# 425          27  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Away
# 474          35  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Away
# 515          28  2023-03-12  14:00  Premier League  Matchweek 27  Sun  Away
# 556          28  2023-03-11  17:30  Premier League  Matchweek 27  Sat  Home
# 601          32  2023-03-12  16:30  Premier League  Matchweek 27  Sun  Away
# 645          32  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Away
# 690          32  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Home
# 741          38  2023-03-12  14:00  Premier League  Matchweek 27  Sun  Home
# 786          31  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Home
# 828          29  2023-03-11  15:00  Premier League  Matchweek 27  Sat  Home
# 874          34  2023-03-12  14:00  Premier League  Matchweek 27  Sun  Away
# 916          29  2023-03-11  12:30  Premier League  Matchweek 27  Sat  Home
#
#     result   gf   ga  ... pass  int  tkl+int  clr  err  season  \
# 36     NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 89     NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 146    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 199    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 249    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 296    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 340    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 383    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 425    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 474    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 515    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 556    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 601    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 645    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 690    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 741    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 786    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 828    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 874    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
# 916    NaN  NaN  NaN  ...  NaN  NaN      NaN  NaN  NaN    2023
#
#                        team  target  venue_code  opp_code
# 36                  Arsenal       0           0         9
# 89           ManchesterCity       0           0         7
# 146        ManchesterUnited       0           1        18
# 199        TottenhamHotspur       0           1        17
# 249               Liverpool       0           0         2
# 296         NewcastleUnited       0           1        22
# 340                  Fulham       0           1         0
# 383   BrightonandHoveAlbion       0           0        10
# 425               Brentford       0           0         8
# 474                 Chelsea       0           0        11
# 515              AstonVilla       0           0        21
# 556           CrystalPalace       0           1        13
# 601  WolverhamptonWanderers       0           0        15
# 645        NottinghamForest       0           0        19
# 690           LeicesterCity       0           1         6
# 741           WestHamUnited       0           1         1
# 786             LeedsUnited       0           1         4
# 828                 Everton       0           1         3
# 874             Southampton       0           0        14
# 916             Bournemouth       0           1        12
#
# [20 rows x 98 columns]

# %%
#Select the data up to the week before the week you want to predict
dataf=data[data['date']<'2023-03-13']

# %%
dataf["g/sot"] = dataf["g/sot"].fillna(dataf["g/sot"].mean())
# Out:
# C:\Users\enriq\AppData\Local\Temp\ipykernel_44288\1122965318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataf["g/sot"] = dataf["g/sot"].fillna(dataf["g/sot"].mean())

# %%
dataf.columns
# Out:
# Index(['unnamed: 0', 'date', 'time', 'comp', 'round', 'day', 'venue', 'result',
#        'gf', 'ga', 'opponent', 'xg_x', 'xga', 'poss', 'gls', 'sh_x', 'sot',
#        'sot%', 'g/sh', 'g/sot', 'dist', 'fk', 'pk', 'pkatt', 'xg_y', 'npxg',
#        'npxg/sh', 'g-xg', 'np:g-xg', 'cmp', 'cmp.1', 'cmp.2', 'cmp.3', 'att_x',
#        'att_x.1', 'att_x.2', 'att_x.3', 'cmp%', 'cmp%.1', 'cmp%.2', 'cmp%.3',
#        'totdist', 'prgdist', 'ast', 'xag', 'xa', 'kp', '1/3', 'ppa', 'crspa',
#        'prgp', 'sca', 'passlive', 'passlive.1', 'passdead', 'passdead.1', 'to',
#        'to.1', 'fld', 'fld.1', 'def', 'def.1', 'gca', 'passlive.2',
#        'passlive.3', 'passdead.2', 'passdead.3', 'to.2', 'to.3', 'sh_y',
#        'sh_y.1', 'fld.2', 'fld.3', 'def.2', 'def.3', 'tkl', 'tkl.1', 'tklw',
#        'def 3rd', 'mid 3rd', 'att 3rd', 'tkl.2', 'tkl.3', 'att_y', 'tkl%',
#        'lost', 'blocks', 'sh', 'pass', 'int', 'tkl+int', 'clr', 'err',
#        'season', 'team', 'target', 'venue_code', 'opp_code'],
#       dtype='object')

# %%
dataf.shape
# Out:
# (1284, 98)

# %% [markdown]
# eliminate_columns=['date', 'time', 'comp', 'round', 'day','venue','season','unnamed: 0','team']
# columns_data_ridge=dataf.drop(eliminate_columns,axis=1).columns
#
# data_ridge=dataf[['unnamed: 0','date','team']+list(columns_data_ridge)]
# data_ridge

# %%
eliminate_columns=['date', 'time', 'comp', 'round', 'day','venue','season','unnamed: 0','team','gf','ga','opponent','result']
data_ridge=dataf.drop(eliminate_columns,axis=1)

# %%
def rolling(df,cols,new_cols):
    df=df.sort_values('date')
    rolling_stats=df[cols].rolling(3,closed='left').mean()
    df[new_cols] = rolling_stats
    df = df.dropna(subset=new_cols)
    return df

# %%
#cols=[ "gf", "ga","sot%","g/sot","xg_x","xga","poss",'prgp','g/sh','dist','cmp','att_x','int','clr','lost']

cols=data_ridge.columns

new_cols = [f"{c}_rolling" for c in cols]

# %%
dataf[cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1284 entries, 0 to 1883
# Data columns (total 85 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   xg_x        1262 non-null   float64
#  1   xga         1262 non-null   float64
#  2   poss        1262 non-null   float64
#  3   gls         1262 non-null   float64
#  4   sh_x        1262 non-null   float64
#  5   sot         1262 non-null   float64
#  6   sot%        1262 non-null   float64
#  7   g/sh        1262 non-null   float64
#  8   g/sot       1284 non-null   float64
#  9   dist        1262 non-null   float64
#  10  fk          1262 non-null   float64
#  11  pk          1262 non-null   float64
#  12  pkatt       1262 non-null   float64
#  13  xg_y        1262 non-null   float64
#  14  npxg        1262 non-null   float64
#  15  npxg/sh     1262 non-null   float64
#  16  g-xg        1262 non-null   float64
#  17  np:g-xg     1262 non-null   float64
#  18  cmp         1262 non-null   float64
#  19  cmp.1       1262 non-null   float64
#  20  cmp.2       1262 non-null   float64
#  21  cmp.3       1262 non-null   float64
#  22  att_x       1262 non-null   float64
#  23  att_x.1     1262 non-null   float64
#  24  att_x.2     1262 non-null   float64
#  25  att_x.3     1262 non-null   float64
#  26  cmp%        1262 non-null   float64
#  27  cmp%.1      1262 non-null   float64
#  28  cmp%.2      1262 non-null   float64
#  29  cmp%.3      1262 non-null   float64
#  30  totdist     1262 non-null   float64
#  31  prgdist     1262 non-null   float64
#  32  ast         1262 non-null   float64
#  33  xag         1262 non-null   float64
#  34  xa          1262 non-null   float64
#  35  kp          1262 non-null   float64
#  36  1/3         1262 non-null   float64
#  37  ppa         1262 non-null   float64
#  38  crspa       1262 non-null   float64
#  39  prgp        1262 non-null   float64
#  40  sca         1262 non-null   float64
#  41  passlive    1262 non-null   float64
#  42  passlive.1  1262 non-null   float64
#  43  passdead    1262 non-null   float64
#  44  passdead.1  1262 non-null   float64
#  45  to          1262 non-null   float64
#  46  to.1        1262 non-null   float64
#  47  fld         1262 non-null   float64
#  48  fld.1       1262 non-null   float64
#  49  def         1262 non-null   float64
#  50  def.1       1262 non-null   float64
#  51  gca         1262 non-null   float64
#  52  passlive.2  1262 non-null   float64
#  53  passlive.3  1262 non-null   float64
#  54  passdead.2  1262 non-null   float64
#  55  passdead.3  1262 non-null   float64
#  56  to.2        1262 non-null   float64
#  57  to.3        1262 non-null   float64
#  58  sh_y        1262 non-null   float64
#  59  sh_y.1      1262 non-null   float64
#  60  fld.2       1262 non-null   float64
#  61  fld.3       1262 non-null   float64
#  62  def.2       1262 non-null   float64
#  63  def.3       1262 non-null   float64
#  64  tkl         1262 non-null   float64
#  65  tkl.1       1262 non-null   float64
#  66  tklw        1262 non-null   float64
#  67  def 3rd     1262 non-null   float64
#  68  mid 3rd     1262 non-null   float64
#  69  att 3rd     1262 non-null   float64
#  70  tkl.2       1262 non-null   float64
#  71  tkl.3       1262 non-null   float64
#  72  att_y       1262 non-null   float64
#  73  tkl%        1262 non-null   float64
#  74  lost        1262 non-null   float64
#  75  blocks      1262 non-null   float64
#  76  sh          1262 non-null   float64
#  77  pass        1262 non-null   float64
#  78  int         1262 non-null   float64
#  79  tkl+int     1262 non-null   float64
#  80  clr         1262 non-null   float64
#  81  err         1262 non-null   float64
#  82  target      1284 non-null   int32
#  83  venue_code  1284 non-null   int8
#  84  opp_code    1284 non-null   int8
# dtypes: float64(82), int32(1), int8(2)
# memory usage: 840.1 KB

# %% [markdown]
# camibar dataf por data

# %%
matches_rolling = dataf.groupby("team").apply(lambda x: rolling(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.shape
# Out:
# (1211, 183)

# %%
rr = RidgeClassifier(alpha=1)

split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, 
                                n_features_to_select=15, 
                                direction="forward",
                                cv=split,
                                n_jobs=1
                               )

# %%
matches_rolling.columns
# Out:
# Index(['unnamed: 0', 'date', 'time', 'comp', 'round', 'day', 'venue', 'result',
#        'gf', 'ga',
#        ...
#        'blocks_rolling', 'sh_rolling', 'pass_rolling', 'int_rolling',
#        'tkl+int_rolling', 'clr_rolling', 'err_rolling', 'target_rolling',
#        'venue_code_rolling', 'opp_code_rolling'],
#       dtype='object', length=183)

# %%
removed_columns=['unnamed: 0','date', 'time', 'comp', 'round', 'day','venue','season','unnamed: 0','team','gf','ga','opponent','result','g/sot', 'g/sh_rolling', 'g/sot_rolling', 'pk_rolling', 'pkatt_rolling', 'npxg/sh_rolling', 'fld.1_rolling', 'def.1_rolling', 'fld.3_rolling', 'def.3_rolling', 'target_rolling', 'venue_code_rolling','target']
selected_columns = matches_rolling.columns[~matches_rolling.columns.isin(removed_columns)]
selected_columns
# Out:
# Index(['xg_x', 'xga', 'poss', 'gls', 'sh_x', 'sot', 'sot%', 'g/sh', 'dist',
#        'fk',
#        ...
#        'tkl%_rolling', 'lost_rolling', 'blocks_rolling', 'sh_rolling',
#        'pass_rolling', 'int_rolling', 'tkl+int_rolling', 'clr_rolling',
#        'err_rolling', 'opp_code_rolling'],
#       dtype='object', length=157)

# %%
# Select the numeric columns
num_cols = matches_rolling.select_dtypes(include=['float64', 'int64'])

# Filter columns that have values ​​between 0 and 1
cols_filt = (num_cols >= 0) & (num_cols <= 1)
cols_filt = cols_filt.all()

# Get the names of the columns that meet the condition
cols_names = cols_filt[cols_filt == True].index.tolist()

print(cols_names)
# Out:
# ['g/sot', 'g/sh_rolling', 'g/sot_rolling', 'pk_rolling', 'pkatt_rolling', 'npxg/sh_rolling', 'fld.1_rolling', 'def.1_rolling', 'fld.3_rolling', 'def.3_rolling', 'target_rolling', 'venue_code_rolling']

# %%
#Standardization
scaler = MinMaxScaler()
matches_rolling[selected_columns] = scaler.fit_transform(matches_rolling[selected_columns])

# %%
matches_rolling=matches_rolling.dropna()

# %%
sfs.fit(matches_rolling[selected_columns],matches_rolling['target'] )
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=15, n_jobs=1)

# %%
matches_rolling.dropna().shape
# Out:
# (1191, 183)

# %%
predictors=list(selected_columns[sfs.get_support()])
predictors
# Out:
# ['xga',
#  'gls',
#  'g/sh',
#  'crspa',
#  'passdead',
#  'def.1',
#  'passdead.2',
#  'def.3',
#  'att 3rd',
#  'clr',
#  '1/3_rolling',
#  'crspa_rolling',
#  'to_rolling',
#  'to.2_rolling',
#  'err_rolling']

# %% [markdown]
# xGA: Expected Goals Against. It's a metric that estimates the number of goals a team should have conceded based on the quality of the scoring opportunities they have faced.
#
# GLS: Goals. It represents the number of goals scored by a team or player.
#
# G/Sh: Goals per Shot. It's a metric that calculates the efficiency of a player or team in converting shots into goals.
#
# CrSpA: Crosses into the Area. It represents the number of times a team or player has attempted to send a cross into the penalty area from the flanks of the field.
#
# PassDead: Dead Passes. It's the number of passes that don't reach their intended target and go out of play.
#
# Def.1, PassDead.2, Def.3: These are likely defensive metrics that track various defensive actions, such as clearances, interceptions, tackles, and blocks.
#
# Att 3rd: Passes into the Attacking Third. It represents the number of passes a team or player has made into the attacking third of the field.
#
# Clr: Clearances. It's the number of times a player or team has successfully cleared the ball away from their own penalty area.
#
# 1/3_rolling, CrSpA_rolling, TO_rolling, TO.2_rolling, Err_rolling: Rolling averages of the above-mentioned metrics, calculated over a specific number of matches.

# %%
train = matches_rolling[matches_rolling["date"] < '2023-01-01']
test = matches_rolling[matches_rolling["date"] > '2023-01-01']

# %%
matches_rolling
# Out:
#       unnamed: 0        date   time            comp         round  day venue  \
# 1169           4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home
# 1170           5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away
# 1172           7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home
# 1173           8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away
# 1174           9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home
# ...          ...         ...    ...             ...           ...  ...   ...
# 596           27  2023-02-11  15:00  Premier League  Matchweek 23  Sat  Away
# 597           28  2023-02-18  15:00  Premier League  Matchweek 24  Sat  Home
# 598           29  2023-02-24  20:00  Premier League  Matchweek 25  Fri  Away
# 599           30  2023-03-01  20:00  Premier League   Matchweek 7  Wed  Away
# 600           31  2023-03-04  15:00  Premier League  Matchweek 26  Sat  Home
#
#      result gf ga  ... blocks_rolling  sh_rolling  pass_rolling  int_rolling  \
# 1169      W  1  0  ...       0.603448    0.769231      0.414634     0.319149
# 1170      W  1  0  ...       0.689655    1.000000      0.390244     0.234043
# 1172      W  3  1  ...       0.534483    0.769231      0.317073     0.340426
# 1173      D  0  0  ...       0.500000    0.461538      0.463415     0.297872
# 1174      D  2  2  ...       0.500000    0.500000      0.439024     0.468085
# ...     ... .. ..  ...            ...         ...           ...          ...
# 596       W  2  1  ...       0.741379    0.846154      0.560976     0.191489
# 597       L  0  1  ...       0.637931    0.730769      0.487805     0.234043
# 598       D  1  1  ...       0.551724    0.769231      0.341463     0.042553
# 599       L  0  2  ...       0.379310    0.423077      0.317073     0.170213
# 600       W  1  0  ...       0.344828    0.346154      0.317073     0.276596
#
#       tkl+int_rolling  clr_rolling  err_rolling  target_rolling  \
# 1169         0.267327     0.396226     0.166667        0.000000
# 1170         0.297030     0.424528     0.166667        0.333333
# 1172         0.326733     0.679245     0.333333        0.666667
# 1173         0.435644     0.584906     0.166667        1.000000
# 1174         0.435644     0.603774     0.166667        0.666667
# ...               ...          ...          ...             ...
# 596          0.287129     0.792453     0.500000        0.666667
# 597          0.366337     0.745283     0.500000        0.666667
# 598          0.306931     0.679245     0.333333        0.666667
# 599          0.386139     0.462264     0.166667        0.333333
# 600          0.435644     0.311321     0.000000        0.000000
#
#       venue_code_rolling  opp_code_rolling
# 1169            0.333333          0.267857
# 1170            0.666667          0.500000
# 1172            0.333333          0.482143
# 1173            0.666667          0.589286
# 1174            0.333333          0.375000
# ...                  ...               ...
# 596             0.666667          0.696429
# 597             0.333333          0.642857
# 598             0.666667          0.446429
# 599             0.333333          0.392857
# 600             0.333333          0.285714
#
# [1191 rows x 183 columns]

# %% [markdown]
# Random Forest Model

# %%
model = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches_rolling[matches_rolling["date"] < '2023-01-01']
test = matches_rolling[(matches_rolling["date"] > '2023-01-01')& (matches_rolling["date"]<'2023-03-11')].dropna()

# %%
model.fit(train[predictors],train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
predictors
# Out:
# ['xga',
#  'gls',
#  'g/sh',
#  'crspa',
#  'passdead',
#  'def.1',
#  'passdead.2',
#  'def.3',
#  'att 3rd',
#  'clr',
#  '1/3_rolling',
#  'crspa_rolling',
#  'to_rolling',
#  'to.2_rolling',
#  'err_rolling']

# %%
preds=model.predict(test[predictors])

# %%
f1 = f1_score(test["target"], preds, average='binary')
f1
# Out:
# 0.6909090909090909
